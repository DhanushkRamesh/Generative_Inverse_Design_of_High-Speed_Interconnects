# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

#Loading the data
csv_path = "~/mece_project_inverse_model/Generative_Inverse_Design_of_High-Speed_Interconnects/data/raw/Universal-Diff-SI-Array/parameter.csv"
df = pd.read_csv(csv_path)

# Display the first few rows of the DataFrame
#inspect the data
print ("DataFrame shape:", df.shape)
print ("DataFrame columns:", df.columns.tolist())
print ("DataFrame info:")
df.info()
print ("\n---First few rows of the DataFrame---")
display(df.head())
# Out:
# DataFrame shape: (1916, 16)
# DataFrame columns: ['SIM_ID', 'PERMITTIVITY', 'CONDUCTIVITY', 'LOSSTANGENT', 'TDIEL', 'TMET', 'LAYER_AMOUNT', 'VIAS_X_AMOUNT', 'VIAS_Y_AMOUNT', 'VIA_RADIUS', 'SIMULATION', 'ANTIPAD_RADIUS', 'PITCH', 'SIGNAL_AMOUNT', 'GROUND_AMOUNT', 'POWER_AMOUNT']
# DataFrame info:
# <class 'pandas.DataFrame'>
# RangeIndex: 1916 entries, 0 to 1915
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   SIM_ID          1916 non-null   int64
#  1   PERMITTIVITY    1916 non-null   float64
#  2   CONDUCTIVITY    1916 non-null   float64
#  3   LOSSTANGENT     1916 non-null   float64
#  4   TDIEL           1916 non-null   float64
#  5   TMET            1916 non-null   float64
#  6   LAYER_AMOUNT    1916 non-null   float64
#  7   VIAS_X_AMOUNT   1916 non-null   float64
#  8   VIAS_Y_AMOUNT   1916 non-null   float64
#  9   VIA_RADIUS      1916 non-null   float64
# ...

# %%
#checking for missing values
print ("Missing values in each column:")
print (df.isnull().sum())

#checking for duplicates
num_duplicates = df.duplicated().sum()
print (f"Number of duplicate rows: {num_duplicates}")

#summary statistics
print ("Summary statistics for numerical columns:")
print (df.describe())
# Out:
# Missing values in each column:
# SIM_ID            0
# PERMITTIVITY      0
# CONDUCTIVITY      0
# LOSSTANGENT       0
# TDIEL             0
# TMET              0
# LAYER_AMOUNT      0
# VIAS_X_AMOUNT     0
# VIAS_Y_AMOUNT     0
# VIA_RADIUS        0
# SIMULATION        0
# ANTIPAD_RADIUS    0
# PITCH             0
# SIGNAL_AMOUNT     0
# GROUND_AMOUNT     0
# POWER_AMOUNT      0
# dtype: int64
# Number of duplicate rows: 0
# Summary statistics for numerical columns:
#             SIM_ID  PERMITTIVITY  CONDUCTIVITY  LOSSTANGENT        TDIEL  \
# count  1916.000000   1916.000000  1.916000e+03  1916.000000  1916.000000
# mean   4996.241649      3.611604  4.899999e+07     0.015168    42.038524
# std    2885.841746      0.641463  5.254591e+06     0.008825    21.932115
# min      17.000000      2.500231  4.000518e+07     0.000155     3.293455
# 25%    2498.000000      3.057282  4.444549e+07     0.007441    23.107297
# ...

# %%
#finding the maximum and minimum values for each parameter
print ("Maximum values for each parameter:")
print (df.max())
print ("\nMinimum values for each parameter:")
print (df.min())
# Out:
# Maximum values for each parameter:
# SIM_ID                       9999
# PERMITTIVITY             4.699781
# CONDUCTIVITY      57986261.822743
# LOSSTANGENT              0.029995
# TDIEL                   79.977632
# TMET                     4.098909
# LAYER_AMOUNT                 48.0
# VIAS_X_AMOUNT                 7.0
# VIAS_Y_AMOUNT                 7.0
# VIA_RADIUS              19.979403
# SIMULATION           sim_pkg_9999
# ANTIPAD_RADIUS          38.670885
# PITCH                    78.17221
# SIGNAL_AMOUNT                28.0
# GROUND_AMOUNT                32.0
# POWER_AMOUNT                 10.0
# dtype: object
#
# Minimum values for each parameter:
# SIM_ID                         17
# PERMITTIVITY             2.500231
# CONDUCTIVITY      40005179.157498
# LOSSTANGENT              0.000155
# TDIEL                    3.293455
# TMET                      0.70012
# LAYER_AMOUNT                  4.0
# VIAS_X_AMOUNT                 3.0
# VIAS_Y_AMOUNT                 3.0
# ...
