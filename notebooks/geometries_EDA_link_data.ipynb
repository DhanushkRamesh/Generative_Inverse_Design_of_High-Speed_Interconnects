# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

#Loading the data
csv_path = "~/mece_project_inverse_model/Generative_Inverse_Design_of_High-Speed_Interconnects/data/raw/Universal-Diff-SI-Link/parameter.csv"
df = pd.read_csv(csv_path)

# Display the first few rows of the DataFrame
#inspect the data
print ("DataFrame shape:", df.shape)
print ("DataFrame columns:", df.columns.tolist())
print ("DataFrame info:")
df.info()
print ("\n---First few rows of the DataFrame---")
display(df.head())
# Out:
# DataFrame shape: (1073, 18)
# DataFrame columns: ['SIM_ID', 'PERMITTIVITY', 'CONDUCTIVITY', 'LOSTANGENT', 'TDIEL', 'TMET', 'LAYER_AMOUNT', 'VIAS_X_AMOUNT', 'VIAS_Y_AMOUNT', 'VIA_RADIUS', 'LENGTH', 'SL_WIDTH', 'SIMULATION', 'ANTIPAD_RADIUS', 'PITCH', 'SIGNAL_AMOUNT', 'GROUND_AMOUNT', 'POWER_AMOUNT']
# DataFrame info:
# <class 'pandas.DataFrame'>
# RangeIndex: 1073 entries, 0 to 1072
# Data columns (total 18 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   SIM_ID          1073 non-null   int64
#  1   PERMITTIVITY    1073 non-null   float64
#  2   CONDUCTIVITY    1073 non-null   float64
#  3   LOSTANGENT      1073 non-null   float64
#  4   TDIEL           1073 non-null   float64
#  5   TMET            1073 non-null   float64
#  6   LAYER_AMOUNT    1073 non-null   float64
#  7   VIAS_X_AMOUNT   1073 non-null   float64
#  8   VIAS_Y_AMOUNT   1073 non-null   float64
#  9   VIA_RADIUS      1073 non-null   float64
# ...

# %%
#checking for missing values
print ("Missing values in each column:")
print (df.isnull().sum())

#checking for duplicates
num_duplicates = df.duplicated().sum()
print (f"Number of duplicate rows: {num_duplicates}")

#summary statistics
print ("Summary statistics for numerical columns:")
print (df.describe())
# Out:
# Missing values in each column:
# SIM_ID            0
# PERMITTIVITY      0
# CONDUCTIVITY      0
# LOSTANGENT        0
# TDIEL             0
# TMET              0
# LAYER_AMOUNT      0
# VIAS_X_AMOUNT     0
# VIAS_Y_AMOUNT     0
# VIA_RADIUS        0
# LENGTH            0
# SL_WIDTH          0
# SIMULATION        0
# ANTIPAD_RADIUS    0
# PITCH             0
# SIGNAL_AMOUNT     0
# GROUND_AMOUNT     0
# POWER_AMOUNT      0
# dtype: int64
# Number of duplicate rows: 0
# Summary statistics for numerical columns:
#             SIM_ID  PERMITTIVITY  CONDUCTIVITY   LOSTANGENT        TDIEL  \
# count  1073.000000   1073.000000  1.073000e+03  1073.000000  1073.000000
# mean   3156.787512      3.635307  4.886822e+07     0.015069    27.934871
# std    1831.020847      0.626773  5.164623e+06     0.008708    16.963214
# min       2.000000      2.501794  4.000275e+07     0.000195     3.335540
# 25%    1575.000000      3.118901  4.439502e+07     0.007342    14.476937
# ...

# %%
#finding the maximum and minimum values for each parameter
print ("Maximum values for each parameter:")
print (df.max())
print ("\nMinimum values for each parameter:")
print (df.min())
# Out:
# Maximum values for each parameter:
# SIM_ID                       6227
# PERMITTIVITY             4.699485
# CONDUCTIVITY      57979433.582795
# LOSTANGENT               0.029996
# TDIEL                   78.852581
# TMET                     4.096817
# LAYER_AMOUNT                 48.0
# VIAS_X_AMOUNT                 7.0
# VIAS_Y_AMOUNT                 7.0
# VIA_RADIUS              19.921187
# LENGTH               19998.413043
# SL_WIDTH                38.529451
# SIMULATION            sim_pkg_995
# ANTIPAD_RADIUS           28.61765
# PITCH                   59.815366
# SIGNAL_AMOUNT                28.0
# GROUND_AMOUNT                28.0
# POWER_AMOUNT                  9.0
# dtype: object
#
# Minimum values for each parameter:
# SIM_ID                          2
# PERMITTIVITY             2.501794
# CONDUCTIVITY      40002754.823249
# LOSTANGENT               0.000195
# TDIEL                     3.33554
# TMET                     0.700228
# LAYER_AMOUNT                 12.0
# ...
